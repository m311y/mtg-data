# %% [markdown]
# # Magic The Gathering Data in Python

# %% [markdown]
# ### Create the sqlite database and tables from the csv data

# %%
import pandas as pd
import sqlite3
import os

# create the sqlite DB
db = sqlite3.connect("Data/mtg.db")
# read CSV into dataframe
df = pd.read_csv("Data/LEA.csv", header=0, index_col=0)

# convert the pandas dataframe to a sqlite table
df.to_sql("cards", db, if_exists="replace")
df.to_sql("rarity_count", db, if_exists="replace")

def run_query(query):
    return pd.read_sql_query(query,db)




df
df.reset_index()
# Out:
#                  name   manaCost  cmc colorIdentity          artist  number  \
# 0       Air Elemental  {3}{U}{U}  5.0             U  Richard Thomas     NaN
# 1    Ancestral Recall        {U}  1.0             U      Mark Poole     NaN
# 2    Animate Artifact     {3}{U}  4.0             U  Douglas Shuler     NaN
# 3        Animate Dead     {1}{B}  2.0             B  Anson Maddocks     NaN
# 4        Animate Wall        {W}  1.0             W     Dan Frazier     NaN
# ..                ...        ...  ...           ...             ...     ...
# 290        Winter Orb        {2}  2.0           NaN      Mark Tedin     NaN
# 291     Wooden Sphere        {1}  1.0           NaN      Mark Tedin     NaN
# 292   Word of Command     {B}{B}  2.0             B  Jesper Myrfors     NaN
# 293      Wrath of God  {2}{W}{W}  4.0             W  Quinton Hoover     NaN
# 294     Zombie Master  {1}{B}{B}  3.0             B  Jeff A. Menges     NaN
#
# ...

# %% [markdown]
# ### Query the cards table

# %%
query = """
SELECT * 
FROM cards
ORDER BY name;
"""
run_query(query)
# Out:
#                  name   manaCost  cmc colorIdentity          artist number  \
# 0       Air Elemental  {3}{U}{U}  5.0             U  Richard Thomas   None
# 1    Ancestral Recall        {U}  1.0             U      Mark Poole   None
# 2    Animate Artifact     {3}{U}  4.0             U  Douglas Shuler   None
# 3        Animate Dead     {1}{B}  2.0             B  Anson Maddocks   None
# 4        Animate Wall        {W}  1.0             W     Dan Frazier   None
# ..                ...        ...  ...           ...             ...    ...
# 290        Winter Orb        {2}  2.0          None      Mark Tedin   None
# 291     Wooden Sphere        {1}  1.0          None      Mark Tedin   None
# 292   Word of Command     {B}{B}  2.0             B  Jesper Myrfors   None
# 293      Wrath of God  {2}{W}{W}  4.0             W  Quinton Hoover   None
# 294     Zombie Master  {1}{B}{B}  3.0             B  Jeff A. Menges   None
#
# ...

# %% [markdown]
# ### **Query the help table for rarity_count**

# %%
query_table_help = """
select * from PRAGMA_TABLE_INFO('rarity_count');
"""
run_query(query_table_help)
# Out:
#     cid           name     type  notnull dflt_value  pk
# 0     0           name     TEXT        0       None   0
# 1     1       manaCost     TEXT        0       None   0
# 2     2            cmc     REAL        0       None   0
# 3     3  colorIdentity     TEXT        0       None   0
# 4     4         artist     TEXT        0       None   0
# 5     5         number     REAL        0       None   0
# 6     6           type     TEXT        0       None   0
# 7     7           text     TEXT        0       None   0
# 8     8      printings     TEXT        0       None   0
# 9     9         flavor     TEXT        0       None   0
# 10   10         layout     TEXT        0       None   0
# 11   11   multiverseid  INTEGER        0       None   0
# 12   12          power     TEXT        0       None   0
# 13   13      toughness     TEXT        0       None   0
# 14   14         rarity     TEXT        0       None   0
# 15   15       subtypes     TEXT        0       None   0
# ...

# %% [markdown]
# ### **Query the rarity_count table to show the number of each type of card in the set, and the total cards for each rarity**

# %%
query = """
SELECT
    rarity AS 'Rarity'
    , ROUND(AVG(CASE WHEN cmc IS NULL THEN 0 ELSE cmc END)) "Avg Converted Mana Cost"
    , COUNT(CASE WHEN types LIKE "Creature%" THEN 1 END) "Num Creatures"
    , COUNT(CASE WHEN types LIKE "Instant%" THEN 1 END) "Num Instants"
    , COUNT(CASE WHEN types LIKE "Artifact%" THEN 1 END) "Num Artifacts"
    , COUNT(CASE WHEN types LIKE "Sorcery%" THEN 1 END) "Num Sorceries"
    , COUNT(CASE WHEN types LIKE "Enchantment%" THEN 1 END) "Num Enchantments"
    , COUNT(CASE WHEN types LIKE "Land%" THEN 1 END) "Num Lands"
    , COUNT(CASE WHEN types LIKE "Artifact,Creature%" THEN 1 END) "Num Artifact Creatures"
    , COUNT(rarity) AS "Total cards"
FROM rarity_count
GROUP BY rarity
ORDER BY [Total Cards] DESC;
"""
run_query(query)
# Out:
#        Rarity  Avg Converted Mana Cost  Num Creatures  Num Instants  \
# 0        Rare                      2.0             30            15
# 1    Uncommon                      3.0             32             9
# 2      Common                      2.0             26            19
# 3  Basic Land                      0.0              0             0
#
#    Num Artifacts  Num Sorceries  Num Enchantments  Num Lands  \
# 0             27             14                21          9
# 1             20              8                26          0
# 2              0              8                21          0
# 3              0              0                 0         10
#
#    Num Artifact Creatures  Total cards
# 0                       1          116
# 1                       3           95
# 2                       0           74
# 3                       0           10
